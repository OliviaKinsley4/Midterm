# %%
import pandas as pd
df = pd.read_csv('amazon-orders.csv')
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      04/01/19
# 1                    NaN    your_email@gmail.com      04/01/19
# 2                    NaN    your_email@gmail.com      04/01/19
# 3                    NaN    your_email@gmail.com      04/05/19
# 4                    NaN    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        NaN
# ...

# %%
print("Table dimensions are", df.shape)
# Out:
# Table dimensions are (59, 23)

# %%
df = df.fillna(0)
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# /var/folders/wk/hsd1xgg17vlgdvdjbnvsqjy00000gn/T/ipykernel_34535/2463331391.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"] = df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# ...

# %%
df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# /var/folders/wk/hsd1xgg17vlgdvdjbnvsqjy00000gn/T/ipykernel_34535/148570183.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"] = df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# ...

# %%
print("Sum of Amazon purchases is", df["Total Charged"].sum())
print("Mean of Amazon purchases is", df["Total Charged"].mean())
print("Median of Amazon purchases is", df["Total Charged"].median())
print("Most expensive Amazon purchases was", df["Total Charged"].max())
print("Least expensive Amazon purchases was", df["Total Charged"].min())
print("Standard deviation of total charged is", df["Total Charged"].std())
# Out:
# Sum of Amazon purchases is 1777.7300000000002
# Mean of Amazon purchases is 30.131016949152542
# Median of Amazon purchases is 15.95
# Most expensive Amazon purchases was 210.99
# Least expensive Amazon purchases was 1.04
# Standard deviation of total charged is 36.42273246651456

# %%
print("Sum of tax charged is", df["Tax Charged"].sum())
print("Mean of tax charged is",df["Tax Charged"].mean())
print("Median of tax charged is", df["Tax Charged"].median())
print("Maximum of tax charged is", df["Tax Charged"].max( ))
print("Minimum of tax charged is", df["Tax Charged"].min())
print("Standard deviation of tax charged is", df["Tax Charged"].std())
# Out:
# Sum of tax charged is 52.60999999999999
# Mean of tax charged is 0.8916949152542372
# Median of tax charged is 0.0
# Maximum of tax charged is 11.0
# Minimum of tax charged is 0.0
# Standard deviation of tax charged is 1.9304806910254184

# %%
df['Order Month'] = df['Order Date'].dt.to_period("M")
df
# Out:
#    Order Date             Order ID Payment Instrument Type     Website  \
# 0  2019-04-01  112-0000000-0000001             Visa - 0001  Amazon.com
# 1  2019-04-01  112-0000000-0000002             Visa - 0001  Amazon.com
# 2  2019-04-01  112-0000000-0000003             Visa - 0001  Amazon.com
# 3  2019-04-04  112-0000000-0000004             Visa - 0001  Amazon.com
# 4  2019-04-05  112-0000000-0000005             Visa - 0001  Amazon.com
# 5  2019-04-05  112-0000000-0000006             Visa - 0001  Amazon.com
# 6  2019-04-07  112-0000000-0000007             Visa - 0001  Amazon.com
# 7  2019-04-08  112-0000000-0000008             Visa - 0001  Amazon.com
# 8  2019-04-20  112-0000000-0000009             Visa - 0001  Amazon.com
# 9  2019-04-23  112-0000000-0000010             Visa - 0001  Amazon.com
# 10 2019-05-05  112-0000000-0000011             Visa - 0001  Amazon.com
# 11 2019-05-06  112-0000000-0000012             Visa - 0001  Amazon.com
# ...

# %%
Monthly_Spending = df.groupby("Order Month").sum("Total Charged")
Monthly_Spending
# Out:
#              Purchase Order Number  Shipping Address Street 2  Tax Charged  \
# Order Month
# 2019-04                        0.0                        0.0        13.88
# 2019-05                        0.0                        0.0         6.96
# 2019-06                        0.0                        0.0         1.30
# 2019-07                        0.0                        0.0        30.47
#
#              Total Charged  Group Name
# Order Month
# 2019-04             399.17         0.0
# 2019-05             294.08         0.0
# 2019-06             130.35         0.0
# 2019-07             954.13         0.0

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array(Monthly_Spending['Total Charged'])
mylabels = Monthly_Spending.index

plt.pie(y, labels = mylabels)
plt.title("Monthly Spending")
plt.legend(title = "Month", bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array(Monthly_Spending['Tax Charged'])
mylabels = Monthly_Spending.index
plt.pie(y, labels = mylabels)
plt.title("Monthly Taxes")
plt.legend(title = "Month", bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Monthly_Spending['Total Charged'].plot.bar(figsize=(20, 10), color='pink')
plt.title("2019 Orders by Month")
# Out:
# Text(0.5, 1.0, '2019 Orders by Month')

# %%
daily_orders = df.groupby('Order Date').sum()["Total Charged"]
daily_orders.head()
# Out:
# Order Date
# 2019-04-01     63.91
# 2019-04-04    156.12
# 2019-04-05     27.64
# 2019-04-07     40.63
# 2019-04-08     44.99
# Name: Total Charged, dtype: float64

# %%
daily_orders.plot.bar(figsize=(20, 10), color='pink')
plt.title("2019 Orders")
# Out:
# Text(0.5, 1.0, '2019 Orders')

# %%
x1 = df['Order Date']
y1 = np.array(df['Total Charged'])
y2 = np.array(df['Tax Charged'])
plt.figure(figsize = (20, 10))
plt.xticks(rotation = 90)
plt.plot(x1, y1, label = "Total Charged")
plt.plot(x1, y2, label = "Total Taxed")
plt.legend()
plt.title("Amazon Total Costs and Total Taxes over Time")

plt.show()
